# %%
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stock_df = pd.read_csv('https://assets.datacamp.com/production/course_1761/datasets/stocks.csv',) 
stock_df
sns.pairplot(stock_df)

# %%
AAPL = stock_df[['Date','AAPL']]

# %%
AAPL.head(5)
# Out:
#          Date        AAPL
# 0  2000-01-03  111.937502
# 1  2000-01-04  102.500003
# 2  2000-01-05  103.999997
# 3  2000-01-06   94.999998
# 4  2000-01-07   99.500001

# %%
price_AAPL = stock_df['AAPL']
date = stock_df['Date']

# %%
## FROM: http://www.augustkleimo.com/import-and-plot-stock-price-data-with-python-pandas-and-seaborn/
stock_df.set_index('Date',inplace=True)

# %%
stock_df['AAPL'].plot(figsize=(16, 12))

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3521 entries, 2000-01-03 to 2013-12-31
# Data columns (total 4 columns):
# AAPL    3521 non-null float64
# IBM     3521 non-null float64
# CSCO    3521 non-null float64
# MSFT    3521 non-null float64
# dtypes: float64(4)
# memory usage: 137.5+ KB

# %%
AAPL = stock_df['AAPL']
IBM = stock_df['IBM']
CSCO = stock_df['CSCO']
MSFT = stock_df['MSFT']

# %%
AAPL.head(5)
# Out:
# Date
# 2000-01-03    111.937502
# 2000-01-04    102.500003
# 2000-01-05    103.999997
# 2000-01-06     94.999998
# 2000-01-07     99.500001
# Name: AAPL, dtype: float64

# %%
stock_df.columns
# Out:
# Index(['AAPL', 'IBM', 'CSCO', 'MSFT'], dtype='object')
