# %% [markdown]
# # Objective #
# To have a running list of useful python functions, tips and tricks picked up along the way
# This incorporates lessons learned from:
# + Corey Schafer Pandas Series
# + Pandas Cookbook
# + Pandas For Everyone

# %% [markdown]
# # Short-Cuts #

# %% [markdown]
# ## Importing Packages ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading in Data ##

# %%
# 1. Can use Pandas function to read in CSV files
# df = pd.read_csv('filepath')

movie = pd.read_csv('/Users/BrendanErhard/Desktop/Python/Learnings/Books/Pandas Cookbook/Chapter 1/movies.csv')

# %%
# 2. take a peak at the DataFrame
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# 3. check the datatype of each column in a dadtaframe
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
# 4. Can use the 'get_dtype_counts' method to return the counts of each data type
movie.get_dtype_counts()
# Out:
# /Users/BrendanErhard/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
# float64    13
# int64       3
# object     12
# dtype: int64

# %% [markdown]
# ## Inspect the DataFrame ##

# %%
# check out the shape
movie.shape

# note that this is an attribute
# Out:
# (4916, 28)

# %%
# call the info method 
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
# color                        4897 non-null object
# director_name                4814 non-null object
# num_critic_for_reviews       4867 non-null float64
# duration                     4901 non-null float64
# director_facebook_likes      4814 non-null float64
# actor_3_facebook_likes       4893 non-null float64
# actor_2_name                 4903 non-null object
# actor_1_facebook_likes       4909 non-null float64
# gross                        4054 non-null float64
# genres                       4916 non-null object
# actor_1_name                 4909 non-null object
# movie_title                  4916 non-null object
# num_voted_users              4916 non-null int64
# cast_total_facebook_likes    4916 non-null int64
# actor_3_name                 4893 non-null object
# facenumber_in_poster         4903 non-null float64
# ...

# %% [markdown]
# ## How to change the display for the max columns or rows ##
# This allows for easier scrolling to view the entire DataFrame, and conserves space

# %%
# set the max rows and columns
# this should correspond to max # of columns and rows, from output from the info method called
pd.set_option('display.max_columns', 28)
pd.set_option('display.max_rows', 28)

# %% [markdown]
# ## Select a single column of Data as a Series ##
# A Pandas Series is nothing but a column in an excel sheet.
# **1.** Select a Series **2.** value_counts **3.** normalize **4.** count **5.** summary statistics **6.** describe() **7.** quantiles **8.** fillna() **9.** dropna()

# %%
# What is a Series?:
# Pandas Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects

# %%
# Series diagram - need to import packages to embed the picture
from IPython.display import Image
Image('/Users/BrendanErhard/Desktop/Python/Blueprints/Pandas/series_diagram.png')

# %%
# 1. Select a single column from the movie DataFrame
# let's select movie_title
title_series = movie['movie_title']
title_series.head
# Out:
# <bound method NDFrame.head of 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 2                                          Spectre
# 3                            The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens
#                            ...
# 4911                       Signed Sealed Delivered
# 4912                                 The Following
# 4913                          A Plague So Pleasant
# 4914                              Shanghai Calling
# 4915                             My Date with Drew
# Name: movie_title, Length: 4916, dtype: object>

# %%
# 2. One of the most useful methods for the Series is value_counts
# but this is not optimal for unique categorical data such as movie_titles
# it would be better to choose the Director Series where there could be repeats
director_series = movie['director_name']
director_series
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
# now let's us value_counts() on the director series
director_series.value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Martin Scorsese         20
# Clint Eastwood          20
# Ridley Scott            16
#                         ..
# S.R. Bindler             1
# Benh Zeitlin             1
# Jorge Ramírez Suárez     1
# Nat Faxon                1
# E.L. Katz                1
# Name: director_name, Length: 2397, dtype: int64

# %%
# 3. can pass in normalize to value_counts to find the % of each
director_series.value_counts(normalize=True)
# Out:
# Steven Spielberg        0.005401
# Woody Allen             0.004570
# Martin Scorsese         0.004155
# Clint Eastwood          0.004155
# Ridley Scott            0.003324
#                           ...
# S.R. Bindler            0.000208
# Benh Zeitlin            0.000208
# Jorge Ramírez Suárez    0.000208
# Nat Faxon               0.000208
# E.L. Katz               0.000208
# Name: director_name, Length: 2397, dtype: float64

# %%
# 4. to find # of elemeents in a series, there are a few options
# size, count, len()
director_series.size
# Out:
# 4916

# %%
director_series.count()
# Out:
# 4814

# %%
len(director_series)
# Out:
# 4916

# %%
# Note that size and cont() has different values; there are #N/A values
director_series_clean = movie['director_name']
director_series_clean.value_counts(normalize=True, dropna=True)
# Out:
# Steven Spielberg        0.005401
# Woody Allen             0.004570
# Martin Scorsese         0.004155
# Clint Eastwood          0.004155
# Ridley Scott            0.003324
#                           ...
# S.R. Bindler            0.000208
# Benh Zeitlin            0.000208
# Jorge Ramírez Suárez    0.000208
# Nat Faxon               0.000208
# E.L. Katz               0.000208
# Name: director_name, Length: 2397, dtype: float64

# %%
# count # of n/a values
nan = movie['director_name'].isna().sum()
nan
# Out:
# 102

# %%
# find the difference to find # of n/a values
nan_check = len(director_series) - director_series.count()
nan_check
# Out:
# 102

# %%
# 5. find some summary stats for a numerical series - let's use gross
gross = movie['gross']
gross.min(), gross.max(), gross.mean(), gross.median(), gross.std()
# Out:
# (162.0, 760505847.0, 47644514.531820424, 25043962.0, 67372553.83358088)

# %%
# 6. can also use the describe function for a cleaner output
gross.describe()
# Out:
# count    4.054000e+03
# mean     4.764451e+07
# std      6.737255e+07
# min      1.620000e+02
# 25%      5.019656e+06
# 50%      2.504396e+07
# 75%      6.110841e+07
# max      7.605058e+08
# Name: gross, dtype: float64

# %%
# 7. can also specify the quantiles:
gross.quantile([.2, .4, .6, .8, 1.0])
# Out:
# 0.2      2924634.2
# 0.4     15337338.6
# 0.6     36000000.0
# 0.8     74945462.8
# 1.0    760505847.0
# Name: gross, dtype: float64

# %%
# can also find deciles
gross.quantile([.1, .2, .3, .4, .5, .6, .7, .8, .9, 1])
# Out:
# 0.1       374419.1
# 0.2      2924634.2
# 0.3      7914068.6
# 0.4     15337338.6
# 0.5     25043962.0
# 0.6     36000000.0
# 0.7     51431286.3
# 0.8     74945462.8
# 0.9    122902852.2
# 1.0    760505847.0
# Name: gross, dtype: float64

# %%
# 8. can also fill all missing values using the fillna method
director_series_filled = director_series.fillna(0)
director_series.size, director_series.count()
# Out:
# (4916, 4814)

# %%
# 9. now let's drop nas and compare the count
director_series.dropped = director_series.dropna()
director_series.dropped.size, director_series.dropped.count()
# Out:
# (4814, 4814)

# %% [markdown]
# ## Changing the Index ##

# %%
# 1. can use the set_index() method
movie2 = movie.set_index('movie_title')
movie2
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
# 2. Can also set the index, as part of the loading in data step
movie = pd.read_csv('/Users/BrendanErhard/Desktop/Python/Learnings/Books/Pandas Cookbook/Chapter 1/movies.csv', index_col = 'movie_title')
movie
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
# 3. can also revert/reset the index
movie2.reset_index(inplace=True)

# %% [markdown]
# ## Renaming row and column names ##

# %%
# 1. can use the Dictionary method to map the old values to new values

# start by setting the dictionary values
idx_rename = {'Avatar':'Ratava', 'Spectre':'Ertceps'}
col_rename = {'director_name':'Director Name','num_critic_for_reviews':'Critical Reviews'}

# then pass the dictionaires to a new DataFrame using the rename method
movies_renamed = movie.rename(index=idx_rename, columns=col_rename)
movies_renamed.head()
# Out:
#                                             color      Director Name  \
# movie_title
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# movie_title
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# ...

# %% [markdown]
# ## Selecting multiple DataFrame columns ##

# %%
# 1. subset the dataframe and create a new dataframe
movie_condensed = movie2[['movie_title', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name']]
movie_condensed
# Out:
#                                      movie_title      director_name  \
# 0                                         Avatar      James Cameron
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                        Spectre         Sam Mendes
# 3                          The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker
# ...                                          ...                ...
# 4911                     Signed Sealed Delivered        Scott Smith
# 4912                               The Following                NaN
# 4913                        A Plague So Pleasant   Benjamin Roberds
# 4914                            Shanghai Calling        Daniel Hsia
# 4915                           My Date with Drew           Jon Gunn
#
#          actor_1_name      actor_2_name          actor_3_name
# 0         CCH Pounder  Joel David Moore             Wes Studi
# ...

# %%
# 2. let's rename these columns using a dictionary
col_rename = {'movie_title': 'Title', 'director_name': 'Director', 'actor_1_name':'Actor 1',
                                                                   'actor_2_name':'Actor 2',
                                                                   'actor_3_name':'Actor 3'}
movie_condensed_renamed = movie_condensed.rename(columns=col_rename)
movie_condensed_renamed
# Out:
#                                            Title           Director  \
# 0                                         Avatar      James Cameron
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                        Spectre         Sam Mendes
# 3                          The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker
# ...                                          ...                ...
# 4911                     Signed Sealed Delivered        Scott Smith
# 4912                               The Following                NaN
# 4913                        A Plague So Pleasant   Benjamin Roberds
# 4914                            Shanghai Calling        Daniel Hsia
# 4915                           My Date with Drew           Jon Gunn
#
#               Actor 1           Actor 2               Actor 3
# 0         CCH Pounder  Joel David Moore             Wes Studi
# ...

# %%
# 3. get summary stats for the numerical columns and transpose the data
movie2.describe(include = [np.number]).T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
# 4. get summary stats for the Object and Categorical columns
movie2.describe(include=[np.object, pd.Categorical]).T
# Out:
#                 count unique  \
# movie_title      4916   4916
# color            4897      2
# director_name    4814   2397
# actor_2_name     4903   3030
# genres           4916    914
# actor_1_name     4909   2095
# actor_3_name     4893   3519
# plot_keywords    4764   4756
# movie_imdb_link  4916   4916
# language         4904     47
# country          4911     65
# content_rating   4616     18
#
#                                                                top  freq
# movie_title                           Dave Chappelle's Block Party     1
# color                                                        Color  4693
# director_name                                     Steven Spielberg    26
# actor_2_name                                        Morgan Freeman    18
# genres                                                       Drama   233
# actor_1_name                                        Robert De Niro    48
# ...

# %% [markdown]
# ## Beginning Data Analysis ##

# %%
# 1. select the smallest of the largest
movie = pd.read_csv('/Users/BrendanErhard/Desktop/Python/Learnings/Books/Pandas Cookbook/Chapter 1/movies.csv')


movie3 = movie[['movie_title', 'imdb_score', 'gross', 'budget','title_year']].dropna()
movie3.nlargest(50, 'imdb_score').head(10)
# Out:
#                                             movie_title  imdb_score  \
# 1920                           The Shawshank Redemption         9.3
# 3402                                      The Godfather         9.2
# 66                                      The Dark Knight         9.0
# 2791                             The Godfather: Part II         9.0
# 335       The Lord of the Rings: The Return of the King         8.9
# 1857                                   Schindler's List         8.9
# 3295                                       Pulp Fiction         8.9
# 4397                     The Good, the Bad and the Ugly         8.9
# 97                                            Inception         8.8
# 267   The Lord of the Rings: The Fellowship of the Ring         8.8
#
#             gross       budget  title_year
# 1920   28341469.0   25000000.0      1994.0
# 3402  134821952.0    6000000.0      1972.0
# 66    533316061.0  185000000.0      2008.0
# 2791   57300000.0   13000000.0      1974.0
# ...

# %%
# 2. chain the nsmallest method, to find the lowest budget score, of the top 50 imdb-rated movies
movie3.nlargest(50, 'imdb_score').nsmallest(5, 'budget')
# Out:
#                          movie_title  imdb_score       gross     budget  \
# 4801              Children of Heaven         8.5    925402.0   180000.0
# 2215                          Psycho         8.5  32000000.0   806947.0
# 4397  The Good, the Bad and the Ugly         8.9   6100000.0  1200000.0
# 4330                    Modern Times         8.6    163245.0  1500000.0
# 4635                   Seven Samurai         8.7    269061.0  2000000.0
#
#       title_year
# 4801      1997.0
# 2215      1960.0
# 4397      1966.0
# 4330      1936.0
# 4635      1954.0

# %%
# 3. find the highest imdb_score film, by year
movie4 = movie3.set_index('movie_title').sort_values(['title_year', 'imdb_score'], 
                                                    ascending=False).drop_duplicates(subset='title_year')

movie4.head(10)
# Out:
#                             imdb_score        gross       budget  title_year
# movie_title
# Captain America: Civil War         8.2  407197282.0  250000000.0      2016.0
# Baahubali: The Beginning           8.4    6498000.0   18026148.0      2015.0
# Interstellar                       8.6  187991439.0  165000000.0      2014.0
# The Wolf of Wall Street            8.2  116866727.0  100000000.0      2013.0
# The Dark Knight Rises              8.5  448130642.0  250000000.0      2012.0
# Samsara                            8.5    2601847.0    4000000.0      2011.0
# Inception                          8.8  292568851.0  160000000.0      2010.0
# Up                                 8.3  292979556.0  175000000.0      2009.0
# The Dark Knight                    9.0  533316061.0  185000000.0      2008.0
# No End in Sight                    8.3    1430185.0    2000000.0      2007.0

# %%
# 4. find the highest grossing film, by year
movie4_gross = movie3.set_index('movie_title').sort_values(['title_year', 'gross'], 
                                                    ascending=False).drop_duplicates(subset='title_year')
movie4_gross.head(10)
# Out:
#                                  imdb_score        gross       budget  \
# movie_title
# Captain America: Civil War              8.2  407197282.0  250000000.0
# Jurassic World                          7.0  652177271.0  150000000.0
# American Sniper                         7.3  350123553.0   58800000.0
# The Hunger Games: Catching Fire         7.6  424645577.0  130000000.0
# The Avengers                            8.1  623279547.0  220000000.0
# Transformers: Dark of the Moon          6.3  352358779.0  195000000.0
# Toy Story 3                             8.3  414984497.0  200000000.0
# Avatar                                  7.9  760505847.0  237000000.0
# The Dark Knight                         9.0  533316061.0  185000000.0
# Spider-Man 3                            6.2  336530303.0  258000000.0
#
#                                  title_year
# movie_title
# Captain America: Civil War           2016.0
# Jurassic World                       2015.0
# ...

# %% [markdown]
# ## Selecting Series Data with .loc and .iloc##
# The .iloc intexer selects only by integer loation; the .loc indexer selects by label

# %%
# 1. Load the college dataset and select the City series
college = pd.read_csv('/Users/BrendanErhard/Desktop/Python/Blueprints/Pandas/college.csv', index_col = 'INSTNM')
city = college['CITY']
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %%
# 2. use the .iloc integer
city.iloc[3]
# Out:
# 'Huntsville'

# %%
# 3. to select several different integer locations, pass a list to .iloc
city.iloc[[10, 20, 30]]
# Out:
# INSTNM
# Birmingham Southern College                            Birmingham
# George C Wallace State Community College-Hanceville    Hanceville
# Judson College                                             Marion
# Name: CITY, dtype: object

# %%
# 4. to select equally spaced partition of data, use a slice notation
city.iloc[4:50:10]

# this selects every 10th value within the city series, starting with the 4th (0-based index), stopping at the 50th
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %%
# 5. the .loc indexer selects will select based on index labels
city.loc['Judson College']

# this can be thought of as vlookup, where it will select the value for city based on the index value
# Out:
# 'Marion'

# %%
# 6. to select equally spaced partition, do a slice with a step
city.loc['Alabama State University':'Reid State Technical College':8]
# Out:
# INSTNM
# Alabama State University                               Montgomery
# Concordia College Alabama                                   Selma
# George C Wallace State Community College-Hanceville    Hanceville
# Jefferson State Community College                      Birmingham
# University of Mobile                                       Mobile
# Reid State Technical College                            Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# ## Selecting DataFrame rows ##

# %%
# 1. pass an integer to the .iloc index, to select all values for that row
college.iloc[50]
# Out:
# CITY                  Mobile
# STABBR                    AL
# HBCU                       0
# MENONLY                    0
# WOMENONLY                  0
# RELAFFIL                   0
# SATVRMID                 510
# SATMTMID                 518
# DISTANCEONLY               0
# UGDS                   11267
# UGDS_WHITE            0.6149
# UGDS_BLACK            0.2374
# UGDS_HISP             0.0276
# UGDS_ASIAN            0.0345
# UGDS_AIAN             0.0065
# UGDS_NHPI             0.0013
# UGDS_2MOR             0.0247
# UGDS_NRA              0.0382
# UGDS_UNKN             0.0149
# PPTUG_EF              0.1942
# CURROPER                   1
# PCTPELL               0.3906
# PCTFLOAN              0.5729
# UG25ABV               0.2343
# MD_EARN_WNE_P10        37300
# GRAD_DEBT_MDN_SUPP     24711
# Name: University of South Alabama, dtype: object

# %%
# 2. can use a .loc function, to get the same values, but need to use labels
college.loc['University of South Alabama']
# Out:
# CITY                  Mobile
# STABBR                    AL
# HBCU                       0
# MENONLY                    0
# WOMENONLY                  0
# RELAFFIL                   0
# SATVRMID                 510
# SATMTMID                 518
# DISTANCEONLY               0
# UGDS                   11267
# UGDS_WHITE            0.6149
# UGDS_BLACK            0.2374
# UGDS_HISP             0.0276
# UGDS_ASIAN            0.0345
# UGDS_AIAN             0.0065
# UGDS_NHPI             0.0013
# UGDS_2MOR             0.0247
# UGDS_NRA              0.0382
# UGDS_UNKN             0.0149
# PPTUG_EF              0.1942
# CURROPER                   1
# PCTPELL               0.3906
# PCTFLOAN              0.5729
# UG25ABV               0.2343
# MD_EARN_WNE_P10        37300
# GRAD_DEBT_MDN_SUPP     24711
# Name: University of South Alabama, dtype: object

# %% [markdown]
# ## Boolean Statistics ##

# %%
# 1. select movies as index, and narrow down to > 120 minutes
movie_bool = movie.set_index('movie_title', inplace=True)
movie_bool = movie['duration'] > 120
movie_bool.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: duration, dtype: bool

# %%
# 2. sum up the # of movies > 2 hours
movie_bool.sum()
# Out:
# 1039

# %%
# 3. Figure out how many movies out of total, are over 2 hours
movie_bool.value_counts(normalize=True)
# Out:
# False    0.788649
# True     0.211351
# Name: duration, dtype: float64

# %% [markdown]
# ## Constructing multiple boolean conditions ##

# %%
# 1. load in the movie dataset
movie = pd.read_csv('/Users/BrendanErhard/Desktop/Python/Learnings/Books/Pandas Cookbook/Chapter 1/movies.csv', index_col='movie_title')
movie_mul_bool = movie.dropna()
movie_mul_bool.head()
# Out:
#                                           color      director_name  \
# movie_title
# Avatar                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Spectre                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
# John Carter                               Color     Andrew Stanton
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
# The Dark Knight Rises                                      813.0     164.0
# John Carter                                                462.0     132.0
#
#                                           director_facebook_likes  \
# movie_title
# ...

# %%
# 2. determine the criteria
criteria1 = movie_mul_bool.imdb_score > 8
criteria2 = movie_mul_bool.content_rating == 'R'
criteria3 = ((movie_mul_bool.title_year < 2000) | (movie_mul_bool.title_year > 2009))

# %%
# 3. combine all criteria to one variable
criteria_final = criteria1 & criteria2 & criteria3
criteria_final.head()
# Out:
# movie_title
# Avatar                                      False
# Pirates of the Caribbean: At World's End    False
# Spectre                                     False
# The Dark Knight Rises                       False
# John Carter                                 False
# dtype: bool

# %%
 # 4. filter
movie_filter = movie_mul_bool[criteria_final]
movie_filter.head()
# Out:
#                             color          director_name  \
# movie_title
# Mad Max: Fury Road          Color          George Miller
# The Revenant                Color  Alejandro G. Iñárritu
# Terminator 2: Judgment Day  Color          James Cameron
# Django Unchained            Color      Quentin Tarantino
# The Wolf of Wall Street     Color        Martin Scorsese
#
#                             num_critic_for_reviews  duration  \
# movie_title
# Mad Max: Fury Road                           739.0     120.0
# The Revenant                                 556.0     156.0
# Terminator 2: Judgment Day                   210.0     153.0
# Django Unchained                             765.0     165.0
# The Wolf of Wall Street                      606.0     240.0
#
#                             director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Mad Max: Fury Road                            750.0                   943.0
# ...

# %%
# 5. apply filter and sort by imdb_score
movie_ff = movie_filter[['imdb_score', 'director_name', 'duration', 'content_rating', 'title_year']]
movie_ff.head(10).sort_values(by='imdb_score', ascending=False)
# Out:
#                             imdb_score          director_name  duration  \
# movie_title
# Fight Club                         8.8          David Fincher     151.0
# The Matrix                         8.7         Lana Wachowski     136.0
# Saving Private Ryan                8.6       Steven Spielberg     169.0
# Terminator 2: Judgment Day         8.5          James Cameron     153.0
# Django Unchained                   8.5      Quentin Tarantino     165.0
# Braveheart                         8.4             Mel Gibson     178.0
# The Wolf of Wall Street            8.2        Martin Scorsese     240.0
# Mad Max: Fury Road                 8.1          George Miller     120.0
# The Revenant                       8.1  Alejandro G. Iñárritu     156.0
# Shutter Island                     8.1        Martin Scorsese     138.0
#
#                            content_rating  title_year
# movie_title
# Fight Club                              R      1999.0
# ...

# %% [markdown]
# ## Slicing ##

# %% [markdown]
# ## Working with Dates and Times ##

# %% [markdown]
# ## Grouped and Aggregated Calculations ##

# %%
# 1. load the dataset - source from Daniel Chen
df_gapm = pd.read_csv('/Users/BrendanErhard/Desktop/Python/Learnings/Books/Pandas for Everyone/danielchen/gapminder.tsv', sep='\t')
df_gapm.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# 2. For each year in the dataset, what was the average life expectancy?
df_gapm.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
# 3. what if wanted to find the mean across multiple columns of the df?
# can use a list
multi_gapm = df_gapm.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean()
multi_gapm
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# ...                   ...           ...
# 2007 Africa     54.806038   3089.032605
#      Americas   73.608120  11003.031625
#      Asia       70.728485  12473.026870
#      Europe     77.648600  25054.481636
#      Oceania    80.719500  29810.188275
#
# [60 rows x 2 columns]

# %%
# 4. to flatten the Dataframe, and remove the multi-index, can use 'reset index'
flat = multi_gapm.reset_index()
flat
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# ..   ...       ...        ...           ...
# 55  2007    Africa  54.806038   3089.032605
# 56  2007  Americas  73.608120  11003.031625
# 57  2007      Asia  70.728485  12473.026870
# 58  2007    Europe  77.648600  25054.481636
# 59  2007   Oceania  80.719500  29810.188275
#
# [60 rows x 4 columns]

# %%
# 5. Grouped Frequency counts
df_gapm.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %% [markdown]
# ## Importing YouTube Videos ##

# %%
#from IPython.display import YouTubeVideo
#YouTubeVideo('Y-yIWFIybBI', width=900, height=600)

# %% [markdown]
# # [Documentation] #

# %% [markdown]
# ## Styling ##

# %% [markdown]
# ### Building Styles ###

# %%
# style functions can either be passed element-wise
    # use 'applymap'
# or column/ row/table-wise
    # use 'apply'
        # for columns, use axis =0
        # for rows, use axis = 1
        # for the entire table at once, use axis=None
    
# start by creating a random dataframe

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan
df
# Out:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720

# %% [markdown]
# #### Make negative numbes red, and positive numbers black ####

# %%
# need to write a function
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# the cell's style depends only on its value
# so need to use applymap

s = df.style.applymap(color_negative_red)
s
# Out:
# <style  type="text/css" >
#     #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row0_col0 {
#             color:  black;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             color:  black;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row0_col2 {
#             color:  black;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             color:  red;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             color:  red;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row1_col0 {
#             color:  black;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             color:  red;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row1_col2 {
#             color:  red;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row1_col3 {
#             color:  black;
#         }    #T_f6ffc244_6a42_11ea_b682_34363b61e4c4row1_col4 {
#             color:  black;
# ...

# %% [markdown]
# #### Highlights the max value of a Series in Yellow ####

# %%
# write a function
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# this time need to use apply since it is columnt/table-wise
df.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_f7055bdc_6a42_11ea_b682_34363b61e4c4row2_col4 {
#             background-color:  yellow;
#         }    #T_f7055bdc_6a42_11ea_b682_34363b61e4c4row6_col2 {
#             background-color:  yellow;
#         }    #T_f7055bdc_6a42_11ea_b682_34363b61e4c4row8_col1 {
#             background-color:  yellow;
#         }    #T_f7055bdc_6a42_11ea_b682_34363b61e4c4row8_col3 {
#             background-color:  yellow;
#         }    #T_f7055bdc_6a42_11ea_b682_34363b61e4c4row9_col0 {
#             background-color:  yellow;
#         }</style><table id="T_f7055bdc_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# #### method chain value-based color and highlight max ####

# %%
df.style.applymap(color_negative_red).apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row0_col0 {
#             color:  black;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             color:  black;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row0_col2 {
#             color:  black;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             color:  red;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             color:  red;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row1_col0 {
#             color:  black;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             color:  red;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row1_col2 {
#             color:  red;
#             : ;
#         }    #T_f70d91c6_6a42_11ea_b682_34363b61e4c4row1_col3 {
# ...

# %% [markdown]
# #### Highlight combined with subsetting columns ####

# %%
df.style.apply(highlight_max, subset=['C', 'D'])
# Out:
# <style  type="text/css" >
#     #T_f71246da_6a42_11ea_b682_34363b61e4c4row6_col2 {
#             background-color:  yellow;
#         }    #T_f71246da_6a42_11ea_b682_34363b61e4c4row8_col3 {
#             background-color:  yellow;
#         }</style><table id="T_f71246da_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f71246da_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f71246da_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >1</td>
# ...

# %% [markdown]
# #### Color values by color with slicing ####

# %%
df.style.applymap(color_negative_red, subset=pd.IndexSlice[1:5, ['B','C','D']])
# Out:
# <style  type="text/css" >
#     #T_f7164a14_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             color:  red;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row1_col2 {
#             color:  red;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row1_col3 {
#             color:  black;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row2_col1 {
#             color:  red;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row2_col2 {
#             color:  black;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row2_col3 {
#             color:  black;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row3_col1 {
#             color:  black;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row3_col2 {
#             color:  black;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row3_col3 {
#             color:  black;
#         }    #T_f7164a14_6a42_11ea_b682_34363b61e4c4row4_col1 {
#             color:  black;
# ...

# %% [markdown]
# #### Changing Formatting/Display Values ####

# %%
# convert all to % with 2 decimal
df.style.format("{:.2%}")
# Out:
# <style  type="text/css" >
# </style><table id="T_f71bc606_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f71bc606_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f71bc606_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_f71bc606_6a42_11ea_b682_34363b61e4c4row0_col1" class="data row0 col1" >132.92%</td>
#                         <td id="T_f71bc606_6a42_11ea_b682_34363b61e4c4row0_col2" class="data row0 col2" >nan%</td>
# ...

# %%
# convert all to % with 1 decimal
df.style.format("{:.1%}")
# Out:
# <style  type="text/css" >
# </style><table id="T_f71ff582_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f71ff582_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f71ff582_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >100.0%</td>
#                         <td id="T_f71ff582_6a42_11ea_b682_34363b61e4c4row0_col1" class="data row0 col1" >132.9%</td>
#                         <td id="T_f71ff582_6a42_11ea_b682_34363b61e4c4row0_col2" class="data row0 col2" >nan%</td>
# ...

# %%
# use a dictionary to format specific columns
df.style.format({'B':"{:0<4.0f}", 'D': '{:+.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_f7235484_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f7235484_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f7235484_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f7235484_6a42_11ea_b682_34363b61e4c4row0_col1" class="data row0 col1" >1000</td>
#                         <td id="T_f7235484_6a42_11ea_b682_34363b61e4c4row0_col2" class="data row0 col2" >nan</td>
# ...

# %% [markdown]
# #### Built-in styles ####

# %%
# highlight nulls
df.style.highlight_null(null_color='green')
# Out:
# <style  type="text/css" >
#     #T_f728c004_6a42_11ea_b682_34363b61e4c4row0_col2 {
#             background-color:  green;
#         }    #T_f728c004_6a42_11ea_b682_34363b61e4c4row3_col3 {
#             background-color:  green;
#         }</style><table id="T_f728c004_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f728c004_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f728c004_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >1</td>
# ...

# %%
# can create heatmaps based on values
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)
s = df.style.background_gradient(cmap=cm)
s
# Out:
# /Users/BrendanErhard/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_f730f29c_6a42_11ea_b682_34363b61e4c4row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f730f29c_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             background-color:  #188d18;
#             color:  #000000;
#         }    #T_f730f29c_6a42_11ea_b682_34363b61e4c4row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f730f29c_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f730f29c_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f730f29c_6a42_11ea_b682_34363b61e4c4row1_col0 {
#             background-color:  #ccf1cc;
# ...

# %% [markdown]
# #### Bar Charts ####

# %%
# subset and make a bar chart for each value in a column
df.style.bar(subset=['B', 'C', 'D', 'E'], color='blue')
# Out:
# <style  type="text/css" >
#     #T_f736dd9c_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 89.2%, transparent 89.2%);
#         }    #T_f736dd9c_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 13.4%, transparent 13.4%);
#         }    #T_f736dd9c_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 27.6%, transparent 27.6%);
#         }    #T_f736dd9c_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,blue 16.8%, transparent 16.8%);
#         }    #T_f736dd9c_6a42_11ea_b682_34363b61e4c4row1_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %%
# can use align = mid to align it better
# can also pass in a list of colors for positive, negative
df.style.bar(subset=['B', 'C', 'D', 'E'], align='mid', color=['red', 'green'])
# Out:
# <style  type="text/css" >
#     #T_f73ebf30_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.1%, green 49.1%, green 89.2%, transparent 89.2%);
#         }    #T_f73ebf30_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.4%, red 13.4%, red 29.1%, transparent 29.1%);
#         }    #T_f73ebf30_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.6%, red 27.6%, red 52.5%, transparent 52.5%);
#         }    #T_f73ebf30_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.8%, red 16.8%, red 49.1%, transparent 49.1%);
# ...

# %% [markdown]
# #### Other Options ####

# %%
# Precision of values
df.style.applymap(color_negative_red).apply(highlight_max).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row0_col0 {
#             color:  black;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             color:  black;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row0_col2 {
#             color:  black;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             color:  red;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             color:  red;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row1_col0 {
#             color:  black;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             color:  red;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row1_col2 {
#             color:  red;
#             : ;
#         }    #T_f74acbd6_6a42_11ea_b682_34363b61e4c4row1_col3 {
# ...

# %%
# set a caption
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.style.set_caption('Colormaps, with a caption').background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_f7552874_6a42_11ea_b682_34363b61e4c4row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_f7552874_6a42_11ea_b682_34363b61e4c4row0_col1 {
#             background-color:  #188d18;
#             color:  #000000;
#         }    #T_f7552874_6a42_11ea_b682_34363b61e4c4row0_col2 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_f7552874_6a42_11ea_b682_34363b61e4c4row0_col3 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_f7552874_6a42_11ea_b682_34363b61e4c4row0_col4 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_f7552874_6a42_11ea_b682_34363b61e4c4row1_col0 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_f7552874_6a42_11ea_b682_34363b61e4c4row1_col1 {
#             background-color:  #c0eac0;
#             color:  #000000;
# ...

# %%
# add a hover to the table

from IPython.display import HTML

def hover(hover_color="yellow"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = (df.style.set_table_styles(styles)
          .set_caption("Hover to highlight."))
html
# Out:
# <style  type="text/css" >
#     #T_f75892ac_6a42_11ea_b682_34363b61e4c4 tr:hover {
#           background-color: yellow;
#     }    #T_f75892ac_6a42_11ea_b682_34363b61e4c4 th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_f75892ac_6a42_11ea_b682_34363b61e4c4 caption {
#           caption-side: bottom;
#     }</style><table id="T_f75892ac_6a42_11ea_b682_34363b61e4c4" ><caption>Hover to highlight.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f75892ac_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# hide the index
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_f75ac194_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f75ac194_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f75ac194_6a42_11ea_b682_34363b61e4c4row0_col1" class="data row0 col1" >1.32921</td>
#                         <td id="T_f75ac194_6a42_11ea_b682_34363b61e4c4row0_col2" class="data row0 col2" >-0.770033</td>
#                         <td id="T_f75ac194_6a42_11ea_b682_34363b61e4c4row0_col3" class="data row0 col3" >-0.31628</td>
# ...

# %%
# hide columns
df.style.hide_columns(['D', 'E'])
# Out:
# <style  type="text/css" >
# </style><table id="T_f75dae9a_6a42_11ea_b682_34363b61e4c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f75dae9a_6a42_11ea_b682_34363b61e4c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f75dae9a_6a42_11ea_b682_34363b61e4c4row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f75dae9a_6a42_11ea_b682_34363b61e4c4row0_col1" class="data row0 col1" >1.32921</td>
#                         <td id="T_f75dae9a_6a42_11ea_b682_34363b61e4c4row0_col2" class="data row0 col2" >-0.770033</td>
#                             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Fun Stuff ####

# %%
## Widgets
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return df.style.background_gradient(
        cmap=sns.palettes.diverging_palette(h_neg=h_neg, h_pos=h_pos, s=s, l=l,
                                            as_cmap=True)
    )
# Out:
# /Users/BrendanErhard/anaconda3/lib/python3.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# interactive(children=(IntSlider(value=179, description='h_neg', max=359), IntSlider(value=179, description='h_…

# %% [markdown]
# ## Indexing and Selecting Data ##

# %% [markdown]
# ### Basics ###

# %%
# construct a time series data set
dates = pd.date_range('1/1/2020', periods=8)
df = pd.DataFrame(np.random.randn(8, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2020-01-01  1.264103  0.290035 -1.970288  0.803906
# 2020-01-02  1.030550  0.118098 -0.021853  0.046841
# 2020-01-03 -1.628753 -0.392361  1.700973  1.061330
# 2020-01-04  0.695804 -0.435989 -0.332942  0.602135
# 2020-01-05  0.108789  0.036767 -0.538963  0.499178
# 2020-01-06 -0.711952 -0.237001  0.857119 -1.882352
# 2020-01-07  0.420705 -1.069175 -2.576859 -1.224923
# 2020-01-08 -1.156752  0.931304  0.984257  2.226159

# %%
# most basic indexing is:
s = df['A']
s[5]
# Out:
# -0.7119517569571985

# %% [markdown]
# ### Attribute Access ###

# %%
# can access an index on a Series or a DataFrame
# direct as an attribute

sa = pd.Series([1, 2, 3], index=list('abc'))
dfa = df.copy()
sa.b
# Out:
# 2

# %%
dfa.A
# Out:
# 2020-01-01    1.264103
# 2020-01-02    1.030550
# 2020-01-03   -1.628753
# 2020-01-04    0.695804
# 2020-01-05    0.108789
# 2020-01-06   -0.711952
# 2020-01-07    0.420705
# 2020-01-08   -1.156752
# Freq: D, Name: A, dtype: float64

# %%
sa.a = 5
sa
# Out:
# a    5
# b    2
# c    3
# dtype: int64

# %%
dfa.A = list(range(len(dfa.index)))
dfa
# Out:
#             A         B         C         D
# 2020-01-01  0  0.290035 -1.970288  0.803906
# 2020-01-02  1  0.118098 -0.021853  0.046841
# 2020-01-03  2 -0.392361  1.700973  1.061330
# 2020-01-04  3 -0.435989 -0.332942  0.602135
# 2020-01-05  4  0.036767 -0.538963  0.499178
# 2020-01-06  5 -0.237001  0.857119 -1.882352
# 2020-01-07  6 -1.069175 -2.576859 -1.224923
# 2020-01-08  7  0.931304  0.984257  2.226159

# %%
dfa['A'] = list(range(len(dfa.index))) # create a new column
dfa
# Out:
#             A         B         C         D
# 2020-01-01  0  0.290035 -1.970288  0.803906
# 2020-01-02  1  0.118098 -0.021853  0.046841
# 2020-01-03  2 -0.392361  1.700973  1.061330
# 2020-01-04  3 -0.435989 -0.332942  0.602135
# 2020-01-05  4  0.036767 -0.538963  0.499178
# 2020-01-06  5 -0.237001  0.857119 -1.882352
# 2020-01-07  6 -1.069175 -2.576859 -1.224923
# 2020-01-08  7  0.931304  0.984257  2.226159

# %% [markdown]
# ### Slicing ranges ###

# %%
s[:5]
# Out:
# 2020-01-01    1.264103
# 2020-01-02    1.030550
# 2020-01-03   -1.628753
# 2020-01-04    0.695804
# 2020-01-05    0.108789
# Freq: D, Name: A, dtype: float64

# %%
s[::2] # skips every other
# Out:
# 2020-01-01    1.264103
# 2020-01-03   -1.628753
# 2020-01-05    0.108789
# 2020-01-07    0.420705
# Freq: 2D, Name: A, dtype: float64

# %%
s[::-1] # works backwards
# Out:
# 2020-01-08   -1.156752
# 2020-01-07    0.420705
# 2020-01-06   -0.711952
# 2020-01-05    0.108789
# 2020-01-04    0.695804
# 2020-01-03   -1.628753
# 2020-01-02    1.030550
# 2020-01-01    1.264103
# Freq: -1D, Name: A, dtype: float64

# %%
s2 = s.copy()
s2[:5] = 0 # sets first 5 values to 0
s2
# Out:
# 2020-01-01    0.000000
# 2020-01-02    0.000000
# 2020-01-03    0.000000
# 2020-01-04    0.000000
# 2020-01-05    0.000000
# 2020-01-06   -0.711952
# 2020-01-07    0.420705
# 2020-01-08   -1.156752
# Freq: D, Name: A, dtype: float64

# %%
# with DataFrame, slicing insside of [] slices the rows
df[:3] # first 3 values
# Out:
#                    A         B         C         D
# 2020-01-01  1.264103  0.290035 -1.970288  0.803906
# 2020-01-02  1.030550  0.118098 -0.021853  0.046841
# 2020-01-03 -1.628753 -0.392361  1.700973  1.061330

# %%
df[::-1] # works backwards
# Out:
#                    A         B         C         D
# 2020-01-08 -1.156752  0.931304  0.984257  2.226159
# 2020-01-07  0.420705 -1.069175 -2.576859 -1.224923
# 2020-01-06 -0.711952 -0.237001  0.857119 -1.882352
# 2020-01-05  0.108789  0.036767 -0.538963  0.499178
# 2020-01-04  0.695804 -0.435989 -0.332942  0.602135
# 2020-01-03 -1.628753 -0.392361  1.700973  1.061330
# 2020-01-02  1.030550  0.118098 -0.021853  0.046841
# 2020-01-01  1.264103  0.290035 -1.970288  0.803906

# %% [markdown]
# ### Selection by label ###

# %%
# workin with Series and loc
s1 = pd.Series(np.random.randn(6), index=list('abcdef'))
s1
# Out:
# a   -0.418504
# b   -0.333778
# c   -0.147427
# d    1.561308
# e    0.684710
# f    0.029462
# dtype: float64

# %%
s1.loc['c']
# Out:
# -0.14742686894281498

# %%
s1.loc['b']
# Out:
# -0.33377767276877235

# %%
# can also set values, 0:
s1.loc['c':] = 0
s1
# Out:
# a   -0.418504
# b   -0.333778
# c    0.000000
# d    0.000000
# e    0.000000
# f    0.000000
# dtype: float64

# %%
# working with a DataFrame
df1 = pd.DataFrame(np.random.randn(6,4), index=list('abcdef'), columns=list('ABCD'))
df1
# Out:
#           A         B         C         D
# a -0.852475  1.981417 -1.630199 -0.235034
# b -0.164071  0.658480 -1.307892  1.353785
# c -0.128523 -0.973279 -0.694449 -0.048841
# d -0.579608  0.871106 -0.970320  0.423359
# e  1.974245  0.306420  0.999262  0.872336
# f -1.867980  1.230744 -0.128515  0.841706

# %%
df1.loc[['a', 'b', 'c', 'd'],:]
# Out:
#           A         B         C         D
# a -0.852475  1.981417 -1.630199 -0.235034
# b -0.164071  0.658480 -1.307892  1.353785
# c -0.128523 -0.973279 -0.694449 -0.048841
# d -0.579608  0.871106 -0.970320  0.423359

# %%
# accessing via label slices
df1.loc['d':, 'A':'C']
# Out:
#           A         B         C
# d -0.579608  0.871106 -0.970320
# e  1.974245  0.306420  0.999262
# f -1.867980  1.230744 -0.128515

# %%
# can get a cross section using a label
df1.loc['a']
# Out:
# A   -0.852475
# B    1.981417
# C   -1.630199
# D   -0.235034
# Name: a, dtype: float64

# %%
# can get values with a boolean array
df1.loc['a'] > 0
# Out:
# A    False
# B     True
# C    False
# D    False
# Name: a, dtype: bool

# %%
# get all rows, where 'a' > 0
df1.loc[:, df1.loc['a'] > 0]
# Out:
#           B
# a  1.981417
# b  0.658480
# c -0.973279
# d  0.871106
# e  0.306420
# f  1.230744

# %% [markdown]
# ### Slicing with labels ###

# %%
# with a start and stop labels in an index
# the values in between are included
s = pd.Series(list('abcde'), index=[0, 3, 2, 5, 4])
s.loc[3:5]
# Out:
# 3    b
# 2    c
# 5    d
# dtype: object

# %%
s.sort_index()
# Out:
# 0    a
# 2    c
# 3    b
# 4    e
# 5    d
# dtype: object

# %%
s.sort_index().loc[1:6]
# Out:
# 2    c
# 3    b
# 4    e
# 5    d
# dtype: object

# %% [markdown]
# ### Selection by Position ###

# %%
s1 = pd.Series(np.random.randn(5), index=list(range(0, 10, 2)))
s1
# Out:
# 0    1.104534
# 2    0.467185
# 4    0.205180
# 6   -1.282743
# 8    0.811909
# dtype: float64

# %%
s1.iloc[:3]
# Out:
# 0    1.104534
# 2    0.467185
# 4    0.205180
# dtype: float64

# %%
 s1.iloc[3]
# Out:
# -1.2827426223310838

# %%
# can also set values
s1.iloc[3] = 0
s1
# Out:
# 0    1.104534
# 2    0.467185
# 4    0.205180
# 6    0.000000
# 8    0.811909
# dtype: float64

# %%
# now with a DataFrame
df1 = pd.DataFrame(np.random.randn(6, 4), index=list(range(0, 12, 2)),
                  columns=list(range(0, 8, 2)))
df1
# Out:
#            0         2         4         6
# 0   0.093503  0.475621  0.990621 -1.118760
# 2   0.992857  1.389293 -0.382092 -1.755908
# 4   2.106745  0.669489  0.491352  0.007674
# 6  -0.618005 -0.655212  0.132790  0.068961
# 8  -0.353841 -0.899835  0.150078 -1.155116
# 10 -1.638088 -1.438349 -1.666241  0.570318

# %%
# select via integer slicing
df1.iloc[:3]
# Out:
#           0         2         4         6
# 0  0.093503  0.475621  0.990621 -1.118760
# 2  0.992857  1.389293 -0.382092 -1.755908
# 4  2.106745  0.669489  0.491352  0.007674

# %%
df1.iloc[1:5, 2:4]
# Out:
#           4         6
# 2 -0.382092 -1.755908
# 4  0.491352  0.007674
# 6  0.132790  0.068961
# 8  0.150078 -1.155116

# %%
# select via integer list
df1.iloc[[1, 3, 5], [1,3]]
# Out:
#            2         6
# 2   1.389293 -1.755908
# 6  -0.655212  0.068961
# 10 -1.438349  0.570318

# %%
df1.iloc[1:3,:]
# Out:
#           0         2         4         6
# 2  0.992857  1.389293 -0.382092 -1.755908
# 4  2.106745  0.669489  0.491352  0.007674

# %%
df1.iloc[:, 1:3]
# Out:
#            2         4
# 0   0.475621  0.990621
# 2   1.389293 -0.382092
# 4   0.669489  0.491352
# 6  -0.655212  0.132790
# 8  -0.899835  0.150078
# 10 -1.438349 -1.666241

# %% [markdown]
# ### Selection by callable ###

# %%
df1 = pd.DataFrame(np.random.randn(6, 4),
                  index=list('abcdef'),
                  columns=list('ABCD'))
df1
# Out:
#           A         B         C         D
# a -0.791125  0.734733  0.344844  1.703771
# b  0.693211  0.740752 -0.588767 -1.817743
# c  0.602709  1.133553 -0.441582 -0.552599
# d -0.426768 -0.735853  1.145302 -0.174462
# e  0.734268  0.309565 -0.905451  1.881393
# f -0.226389 -0.805255  1.406344  0.648110

# %%
# use lambda to pull in dataframe for all A values > 0; should be empty
df1.loc[lambda df: df['A'] > 0, :]
# Out:
#           A         B         C         D
# b  0.693211  0.740752 -0.588767 -1.817743
# c  0.602709  1.133553 -0.441582 -0.552599
# e  0.734268  0.309565 -0.905451  1.881393

# %%
# use lambda to pull in dataframe for all B values > 0
df1.loc[lambda df: df['B'] > 0, :]
# Out:
#           A         B         C         D
# a -0.791125  0.734733  0.344844  1.703771
# b  0.693211  0.740752 -0.588767 -1.817743
# c  0.602709  1.133553 -0.441582 -0.552599
# e  0.734268  0.309565 -0.905451  1.881393

# %%
# now use lambda to pull in all rows for columns A and B
df1.loc[:, lambda df: ['A', 'B']]
# Out:
#           A         B
# a -0.791125  0.734733
# b  0.693211  0.740752
# c  0.602709  1.133553
# d -0.426768 -0.735853
# e  0.734268  0.309565
# f -0.226389 -0.805255

# %%
# this is the same but uses integers and iloc
df1.iloc[:, lambda df: [0,1]]
# Out:
#           A         B
# a -0.791125  0.734733
# b  0.693211  0.740752
# c  0.602709  1.133553
# d -0.426768 -0.735853
# e  0.734268  0.309565
# f -0.226389 -0.805255

# %%
# can also use lambda with Series
df1['B'].loc[lambda s: s > 0]
# Out:
# a    0.734733
# b    0.740752
# c    1.133553
# e    0.309565
# Name: B, dtype: float64

# %% [markdown]
# ### Reindexing ###

# %%
s.reindex([1, 2, 3])
# Out:
# 1    NaN
# 2      c
# 3      b
# dtype: object

# %% [markdown]
# ### Boolean Indexing ###

# %%
# boolean indexing with a Series
s = pd.Series(range(-3, 4))
s
# Out:
# 0   -3
# 1   -2
# 2   -1
# 3    0
# 4    1
# 5    2
# 6    3
# dtype: int64

# %%
s[s > 0]
# Out:
# 4    1
# 5    2
# 6    3
# dtype: int64

# %%
s[(s < -1) | (s > 0.5)]
# Out:
# 0   -3
# 1   -2
# 4    1
# 5    2
# 6    3
# dtype: int64

# %%
s[~(s < 0)]
# Out:
# 3    0
# 4    1
# 5    2
# 6    3
# dtype: int64

# %%
# can select rows from a DataFrame using  boolean vactor
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2020-01-01  1.264103  0.290035 -1.970288  0.803906
# 2020-01-02  1.030550  0.118098 -0.021853  0.046841
# 2020-01-04  0.695804 -0.435989 -0.332942  0.602135
# 2020-01-05  0.108789  0.036767 -0.538963  0.499178
# 2020-01-07  0.420705 -1.069175 -2.576859 -1.224923

# %%
# list comprehensions and map
# can be used for more complex sorting
df2 = pd.DataFrame({'a': ['one', 'one', 'two', 'three', 'two', 'one', 'six'],
                   'b': ['x', 'y', 'y', 'x', 'y', 'x', 'x'],
                   'c': np.random.randn(7)})

# only want 'two' or 'three'
criterion = df2['a'].map(lambda x: x.startswith('t'))
df2[criterion]
# Out:
#        a  b         c
# 2    two  y -1.491068
# 3  three  x -0.996761
# 4    two  y  0.407163

# %%
# can also use this method; but slower
df2[[x.startswith('t') for x in df2['a']]]
# Out:
#        a  b         c
# 2    two  y -1.491068
# 3  three  x -0.996761
# 4    two  y  0.407163

# %%
# can use multiple criteria
df2[criterion & (df2['b'] == 'x')]
# Out:
#        a  b         c
# 3  three  x -0.996761

# %%
# can select mroe than one axis
df2.loc[criterion & (df2['b'] == 'x'), 'b':'c']
# Out:
#    b         c
# 3  x -0.996761

# %% [markdown]
# ### indexing with isin ###

# %%
# isin() method returns a boolean vecgor that is true
# when the Series element exists in the passed list
# can select row where 1+ columns have values you want

s = pd.Series(np.arange(5), index=np.arange(5)[::-1], dtype='int64')
s
# Out:
# 4    0
# 3    1
# 2    2
# 1    3
# 0    4
# dtype: int64

# %%
s.isin([2, 4, 6])
# Out:
# 4    False
# 3    False
# 2     True
# 1    False
# 0     True
# dtype: bool

# %%
s[s.isin([2, 4, 6])]
# Out:
# 2    2
# 0    4
# dtype: int64

# %%
# can also use this method for index objects
s[s.index.isin([2, 4, 6])]
# Out:
# 4    0
# 2    2
# dtype: int64

# %%
# compare to the following
s.reindex([2, 4, 6])
# Out:
# 2    2.0
# 4    0.0
# 6    NaN
# dtype: float64

# %%
# MultiIndex allows to select a separate lelvel to use
# in the membership check

s_mi = pd.Series(np.arange(6), 
                index = pd.MultiIndex.from_product([[0, 1],
                                                   ['a', 'b', 'c']]))
s_mi
# Out:
# 0  a    0
#    b    1
#    c    2
# 1  a    3
#    b    4
#    c    5
# dtype: int64

# %%
s_mi.iloc[s_mi.index.isin([(1, 'a'), (2, 'b'), (0, 'c')])]
# Out:
# 0  c    2
# 1  a    3
# dtype: int64

# %%
# DataFrame and isin()
# needs to be passed as an array or a dict()
df_i = pd.DataFrame({'vals': [1, 2, 3, 4],
                    'ids': ['a', 'b', 'f', 'n'],
                    'ids2': ['a', 'n', 'c', 'n']})
values = ['a', 'b', 1, 3]
df_i.isin(values)
# Out:
#     vals    ids   ids2
# 0   True   True   True
# 1  False   True  False
# 2   True  False  False
# 3  False  False  False

# %%
# combine isin with any() and all() methods
# to select subsets that meet criteria
value = {'ids': ['a', 'b'], 'ids2':['a', 'c'], 'vals': [1,3]}
row_mask = df_i.isin(values).all(1)
df_i[row_mask]
# Out:
#    vals ids ids2
# 0     1   a    a

# %% [markdown]
# ### The where() method and Masking ###

# %%
# selecting with  boolean vector returns a subset of data
# the where() method will guarantee an output with the same shape

# return only the selected rows
s[s >0]
# Out:
# 3    1
# 2    2
# 1    3
# 0    4
# dtype: int64

# %%
# return a series with the same shape 
s.where(s > 0)
# Out:
# 4    NaN
# 3    1.0
# 2    2.0
# 1    3.0
# 0    4.0
# dtype: float64

# %%
# where() for DataFrames
df[df > 0]
# Out:
#                    A         B         C         D
# 2020-01-01  1.264103  0.290035       NaN  0.803906
# 2020-01-02  1.030550  0.118098       NaN  0.046841
# 2020-01-03       NaN       NaN  1.700973  1.061330
# 2020-01-04  0.695804       NaN       NaN  0.602135
# 2020-01-05  0.108789  0.036767       NaN  0.499178
# 2020-01-06       NaN       NaN  0.857119       NaN
# 2020-01-07  0.420705       NaN       NaN       NaN
# 2020-01-08       NaN  0.931304  0.984257  2.226159

# %%
# identical code as above
df.where(df > 0)
# Out:
#                    A         B         C         D
# 2020-01-01  1.264103  0.290035       NaN  0.803906
# 2020-01-02  1.030550  0.118098       NaN  0.046841
# 2020-01-03       NaN       NaN  1.700973  1.061330
# 2020-01-04  0.695804       NaN       NaN  0.602135
# 2020-01-05  0.108789  0.036767       NaN  0.499178
# 2020-01-06       NaN       NaN  0.857119       NaN
# 2020-01-07  0.420705       NaN       NaN       NaN
# 2020-01-08       NaN  0.931304  0.984257  2.226159

# %%
df.where(df < 0, -df)
# Out:
#                    A         B         C         D
# 2020-01-01 -1.264103 -0.290035 -1.970288 -0.803906
# 2020-01-02 -1.030550 -0.118098 -0.021853 -0.046841
# 2020-01-03 -1.628753 -0.392361 -1.700973 -1.061330
# 2020-01-04 -0.695804 -0.435989 -0.332942 -0.602135
# 2020-01-05 -0.108789 -0.036767 -0.538963 -0.499178
# 2020-01-06 -0.711952 -0.237001 -0.857119 -1.882352
# 2020-01-07 -0.420705 -1.069175 -2.576859 -1.224923
# 2020-01-08 -1.156752 -0.931304 -0.984257 -2.226159

# %%
# mask() is the inverse boolean operation of where
s.mask(s >=0)
# Out:
# 4   NaN
# 3   NaN
# 2   NaN
# 1   NaN
# 0   NaN
# dtype: float64

# %%
df.mask(df >=0)
# Out:
#                    A         B         C         D
# 2020-01-01       NaN       NaN -1.970288       NaN
# 2020-01-02       NaN       NaN -0.021853       NaN
# 2020-01-03 -1.628753 -0.392361       NaN       NaN
# 2020-01-04       NaN -0.435989 -0.332942       NaN
# 2020-01-05       NaN       NaN -0.538963       NaN
# 2020-01-06 -0.711952 -0.237001       NaN -1.882352
# 2020-01-07       NaN -1.069175 -2.576859 -1.224923
# 2020-01-08 -1.156752       NaN       NaN       NaN

# %% [markdown]
# ### the query() Method ###

# %%
# query() allows for selection using an expression
n = 10
df_3 = pd.DataFrame(np.random.rand(n, 3), columns=list('abc'))
df_3
# Out:
#           a         b         c
# 0  0.369133  0.016732  0.852986
# 1  0.309491  0.562927  0.090933
# 2  0.792602  0.029209  0.055727
# 3  0.720350  0.031170  0.482601
# 4  0.711530  0.480505  0.801016
# 5  0.548874  0.602904  0.759279
# 6  0.011562  0.928798  0.618510
# 7  0.800932  0.011953  0.563376
# 8  0.205772  0.270741  0.381124
# 9  0.999151  0.990126  0.763854

# %%
# pure python
# select values where column b between a and c
df_3[(df_3['a'] < df_3['b']) & (df_3['b'] < df_3['c'])]
# Out:
#           a         b         c
# 5  0.548874  0.602904  0.759279
# 8  0.205772  0.270741  0.381124

# %%
# can use query()
df_3.query('(a < b) & (b < c)')
# Out:
#           a         b         c
# 5  0.548874  0.602904  0.759279
# 8  0.205772  0.270741  0.381124

# %%
## MultiIndex query()
n = 10
colors = np.random.choice(['red', 'green'], size=n)
foods = np.random.choice(['eggs', 'ham'], size=n)
colors
# Out:
# array(['red', 'red', 'green', 'green', 'green', 'red', 'red', 'green',
#        'green', 'green'], dtype='<U5')

# %%
foods
# Out:
# array(['eggs', 'ham', 'eggs', 'ham', 'eggs', 'ham', 'eggs', 'eggs',
#        'eggs', 'eggs'], dtype='<U4')

# %%
index = pd.MultiIndex.from_arrays([colors, foods], names=['color', 'food'])
df = pd.DataFrame(np.random.randn(n,2), index=index)
df
# Out:
#                    0         1
# color food
# red   eggs -2.870096  0.351710
#       ham   0.265490  0.105712
# green eggs -0.577698 -0.405382
#       ham   1.090286  1.427272
#       eggs  0.692981  0.185200
# red   ham   0.107431 -0.213213
#       eggs -1.131485  0.311157
# green eggs -0.802332 -1.775168
#       eggs -0.138263 -0.470874
#       eggs -0.313894 -0.308149

# %%
df.query('color == "red"')
# Out:
#                    0         1
# color food
# red   eggs -2.870096  0.351710
#       ham   0.265490  0.105712
#       ham   0.107431 -0.213213
#       eggs -1.131485  0.311157

# %%
# if the levels of the MultiIndex are un-named,
# can refer to them using special names
df.index.names = [None, None]
df
# Out:
#                    0         1
# red   eggs -2.870096  0.351710
#       ham   0.265490  0.105712
# green eggs -0.577698 -0.405382
#       ham   1.090286  1.427272
#       eggs  0.692981  0.185200
# red   ham   0.107431 -0.213213
#       eggs -1.131485  0.311157
# green eggs -0.802332 -1.775168
#       eggs -0.138263 -0.470874
#       eggs -0.313894 -0.308149

# %%
df.query('ilevel_0 == "red"')
# Out:
#                  0         1
# red eggs -2.870096  0.351710
#     ham   0.265490  0.105712
#     ham   0.107431 -0.213213
#     eggs -1.131485  0.311157

# %% [markdown]
# ### query() Use Cases ###

# %%
# can pass the query to both frames
# without having to specify which frame
df = pd.DataFrame(np.random.rand(n,3), columns=list('abc'))
df
# Out:
#           a         b         c
# 0  0.656308  0.319279  0.093756
# 1  0.033036  0.591305  0.148361
# 2  0.271314  0.982476  0.828575
# 3  0.989093  0.993064  0.562847
# 4  0.201010  0.426266  0.338708
# 5  0.909549  0.408612  0.007168
# 6  0.547556  0.117731  0.700375
# 7  0.006594  0.617944  0.457555
# 8  0.170866  0.679263  0.075218
# 9  0.388177  0.275487  0.269712

# %%
df2 = pd.DataFrame(np.random.rand(n +2, 3), columns=df.columns)
df2
# Out:
#            a         b         c
# 0   0.938672  0.778533  0.779487
# 1   0.112340  0.027698  0.410982
# 2   0.864758  0.617209  0.775437
# 3   0.386343  0.369454  0.692170
# 4   0.043705  0.685959  0.986685
# 5   0.075707  0.743433  0.577929
# 6   0.278349  0.769164  0.614356
# 7   0.943653  0.513096  0.704602
# 8   0.730145  0.076124  0.138698
# 9   0.492494  0.176961  0.270393
# 10  0.297375  0.317561  0.703831
# 11  0.007464  0.721012  0.942749

# %%
expr = '0.0 <= a <= c <= 0.5'
map(lambda frame: frame.query(expr), [df, df2])

# %% [markdown]
# ### the in and not i operators ###

# %%
# get all rows where columns 'a' and 'b'
# have overlapping values
df = pd.DataFrame({'a': list('aabbccddeeff'), 'b':list('aaaabbbbcccc'),
                  'c': np.random.randint(5, size=12),
                  'd': np.random.randint(9, size=12)})
df
# Out:
#     a  b  c  d
# 0   a  a  4  7
# 1   a  a  0  5
# 2   b  a  2  4
# 3   b  a  3  1
# 4   c  b  3  5
# 5   c  b  1  3
# 6   d  b  4  6
# 7   d  b  3  5
# 8   e  c  2  5
# 9   e  c  0  3
# 10  f  c  3  3
# 11  f  c  3  3

# %%
df.query('a in b')
# Out:
#    a  b  c  d
# 0  a  a  4  7
# 1  a  a  0  5
# 2  b  a  2  4
# 3  b  a  3  1
# 4  c  b  3  5
# 5  c  b  1  3

# %%
df.query('a not in b')
# Out:
#     a  b  c  d
# 6   d  b  4  6
# 7   d  b  3  5
# 8   e  c  2  5
# 9   e  c  0  3
# 10  f  c  3  3
# 11  f  c  3  3

# %%
# can combine with other expressions
# for very succint queries
df.query('a in b and c < d')
# Out:
#    a  b  c  d
# 0  a  a  4  7
# 1  a  a  0  5
# 2  b  a  2  4
# 4  c  b  3  5
# 5  c  b  1  3

# %% [markdown]
# ### Special use of the == operator with list objects ###

# %%
# can comapre a list of values to a column
# using ==/!==, similar to in/not in
df.query('b == ["a", "b", "c"]')
# Out:
#     a  b  c  d
# 0   a  a  4  7
# 1   a  a  0  5
# 2   b  a  2  4
# 3   b  a  3  1
# 4   c  b  3  5
# 5   c  b  1  3
# 6   d  b  4  6
# 7   d  b  3  5
# 8   e  c  2  5
# 9   e  c  0  3
# 10  f  c  3  3
# 11  f  c  3  3

# %%
df.query('c == [1,2]')
# Out:
#    a  b  c  d
# 2  b  a  2  4
# 5  c  b  1  3
# 8  e  c  2  5

# %%
df.query('c != [1,2]')
# Out:
#     a  b  c  d
# 0   a  a  4  7
# 1   a  a  0  5
# 3   b  a  3  1
# 4   c  b  3  5
# 6   d  b  4  6
# 7   d  b  3  5
# 9   e  c  0  3
# 10  f  c  3  3
# 11  f  c  3  3

# %%
df.query('[1,2] not in c')
# Out:
#     a  b  c  d
# 0   a  a  4  7
# 1   a  a  0  5
# 3   b  a  3  1
# 4   c  b  3  5
# 6   d  b  4  6
# 7   d  b  3  5
# 9   e  c  0  3
# 10  f  c  3  3
# 11  f  c  3  3

# %% [markdown]
# ### Boolean operators ###

# %%
# can negate boolean expressions
# with not or ~
df = pd.DataFrame(np.random.rand(n,3), columns=list('abc'))
df['bools'] = np.random.rand(len(df)) > 0.5
df.query('~bools')
# Out:
#           a         b         c  bools
# 0  0.622849  0.766186  0.858092  False
# 1  0.812693  0.643115  0.614226  False
# 2  0.340738  0.565654  0.240780  False
# 3  0.730156  0.403819  0.517373  False
# 5  0.412662  0.758586  0.177384  False
# 6  0.054690  0.528972  0.060902  False
# 7  0.866173  0.370781  0.154008  False
# 8  0.496243  0.161355  0.060327  False

# %%
df.query('not bools')
# Out:
#           a         b         c  bools
# 0  0.622849  0.766186  0.858092  False
# 1  0.812693  0.643115  0.614226  False
# 2  0.340738  0.565654  0.240780  False
# 3  0.730156  0.403819  0.517373  False
# 5  0.412662  0.758586  0.177384  False
# 6  0.054690  0.528972  0.060902  False
# 7  0.866173  0.370781  0.154008  False
# 8  0.496243  0.161355  0.060327  False

# %%
df.query('not bools') == df[~df['bools']]
# Out:
#       a     b     c  bools
# 0  True  True  True   True
# 1  True  True  True   True
# 2  True  True  True   True
# 3  True  True  True   True
# 5  True  True  True   True
# 6  True  True  True   True
# 7  True  True  True   True
# 8  True  True  True   True

# %% [markdown]
# ### Dictionary-like get() method ###

# %%
s = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
s.get('a')
# Out:
# 1

# %%
s.get('x', default=-1)
# Out:
# -1

# %% [markdown]
# ### the lookup() method ###

# %%
# extract a set of values 
# given a sequence of row labels and column labels
dflookup = pd.DataFrame(np.random.rand(20, 4), columns = ['A', 'B', 'C', 'D'])
dflookup.lookup(list(range(0,10,2)), ['B', 'C', 'A', 'B', 'D'])
# Out:
# array([0.90292395, 0.25763106, 0.53321217, 0.62906264, 0.26041943])

# %% [markdown]
# ## MultiIndex/Advanced indexing ##

# %% [markdown]
# ### creating a MultiIndex/Hierarchal Index###

# %%
arrays = [['bar','bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]

tuples = list(zip(*arrays))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
s = pd.Series(np.random.randn(8), index=index)
s
# Out:
# first  second
# bar    one      -0.860953
#        two       2.290153
# baz    one       1.855787
#        two       1.783182
# foo    one       0.284339
#        two       2.562044
# qux    one      -0.345150
#        two       1.703683
# dtype: float64

# %%
# can use the MUltiIndex from_product
iterables = [['bat', 'baz','foo', 'qux'], ['one', 'two']]
pd.MultiIndex.from_product(iterables, names=['first', 'second'])
# Out:
# MultiIndex([('bat', 'one'),
#             ('bat', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
# can also construct a MultiIndex from a DataFrame
df = pd.DataFrame([['bar', 'one'], ['bar', 'two'],
                 ['foo', 'one'], ['foo', 'two']],
                 columns=['first', 'second'])
pd.MultiIndex.from_frame(df)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two')],
#            names=['first', 'second'])

# %%
# can pass a list of arrays direct to a Series or Dataframe
# to construct a MultiIndex
arrays = [np.array(['bar', 'bar', 'baz','baz', 'foo', 'foo', 'qux', 'qux' ]),
         np.array(['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'])]
s = pd.Series(np.random.randn(8), index=arrays)
s
# Out:
# bar  one   -1.148114
#      two    1.181724
# baz  one   -1.424502
#      two    0.001651
# foo  one   -0.701722
#      two   -0.666407
# qux  one   -0.917166
#      two   -0.468235
# dtype: float64

# %%
df = pd.DataFrame(np.random.randn(8,4), index=arrays)
df
# Out:
#                 0         1         2         3
# bar one  0.596814 -0.246257  0.075064 -0.769670
#     two  0.243496 -1.568489  0.588017 -0.858684
# baz one  1.133199  0.746461 -1.921237 -1.647868
#     two  1.048072 -2.071287 -1.642539  0.050627
# foo one -1.605681  1.446223 -0.862214  0.583665
#     two  0.826654 -0.466383  0.872852  0.757995
# qux one  2.229184  0.534385 -1.274395  1.455240
#     two  0.497288  3.232776  0.462148 -0.184859

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df = pd.DataFrame(np.random.randn(3,8), index=['A', 'B', 'C'], columns=index)
df
# Out:
# first        bar                 baz                 foo                 qux  \
# second       one       two       one       two       one       two       one
# A       0.669589  0.412446 -1.440089  0.404922 -0.150802 -1.171831  0.202731
# B      -0.286190 -0.024610 -0.418880 -0.027225 -0.505521  0.264358  0.308612
# C       0.403577 -0.561692  0.282221  1.653675  0.513604  1.349488  1.270424
#
# first
# second       two
# A      -1.096888
# B      -0.970808
# C      -0.074089

# %%
# get labels for each index location at a particular level
index.get_level_values(0)
# Out:
# Index(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'], dtype='object', name='first')

# %%
index.get_level_values(1)
# Out:
# Index(['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'], dtype='object', name='second')

# %%
## Basic indexing on an axis, with MultiIndex
df['bar']
# Out:
# second       one       two
# A       0.669589  0.412446
# B      -0.286190 -0.024610
# C       0.403577 -0.561692

# %%
df['bar', 'one']
# Out:
# A    0.669589
# B   -0.286190
# C    0.403577
# Name: (bar, one), dtype: float64

# %%
df['bar']['one']
# Out:
# A    0.669589
# B   -0.286190
# C    0.403577
# Name: one, dtype: float64

# %%
s['qux']
# Out:
# one   -0.917166
# two   -0.468235
# dtype: float64

# %% [markdown]
# ### Advanced indexing with hierarchal index ###

# %%
df_t = df.T
df_t
# Out:
#                      A         B         C
# first second
# bar   one     0.669589 -0.286190  0.403577
#       two     0.412446 -0.024610 -0.561692
# baz   one    -1.440089 -0.418880  0.282221
#       two     0.404922 -0.027225  1.653675
# foo   one    -0.150802 -0.505521  0.513604
#       two    -1.171831  0.264358  1.349488
# qux   one     0.202731  0.308612  1.270424
#       two    -1.096888 -0.970808 -0.074089

# %%
df_t.loc[('bar', 'two')]
# Out:
# A    0.412446
# B   -0.024610
# C   -0.561692
# Name: (bar, two), dtype: float64

# %%
# slicing
df_t.loc['bar':'foo']
# Out:
#                      A         B         C
# first second
# bar   one     0.669589 -0.286190  0.403577
#       two     0.412446 -0.024610 -0.561692
# baz   one    -1.440089 -0.418880  0.282221
#       two     0.404922 -0.027225  1.653675
# foo   one    -0.150802 -0.505521  0.513604
#       two    -1.171831  0.264358  1.349488

# %%
#can slice with a range of values
df_t.loc[('baz', 'two'):('qux', 'one')]
# Out:
#                      A         B         C
# first second
# baz   two     0.404922 -0.027225  1.653675
# foo   one    -0.150802 -0.505521  0.513604
#       two    -1.171831  0.264358  1.349488
# qux   one     0.202731  0.308612  1.270424

# %%
df_t.loc[('baz', 'two'):'foo']
# Out:
#                      A         B         C
# first second
# baz   two     0.404922 -0.027225  1.653675
# foo   one    -0.150802 -0.505521  0.513604
#       two    -1.171831  0.264358  1.349488

# %%
## using slicers ##
